# %%
# %matplotlib inline
import random
import thinkstats2
import thinkplot

# %%
t=[random.random() for x in range(0,100)]
pmf_random=thinkstats2.Pmf(t)
cdf_random=thinkstats2.Cdf(t)
thinkplot.Pmf(pmf_random)
thinkplot.Show()
thinkplot.Cdf(cdf_random)
thinkplot.Show()
